-- %% [markdown]
-- # [Projeto_sinonimos]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Projeto_sinonimos]    Script Date: 29/08/2024 10:27:08 ******/
CREATE DATABASE [Projeto_sinonimos]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'sinonimos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\sinonimos.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'sinonimos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\sinonimos_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Projeto_sinonimos] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Projeto_sinonimos].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Projeto_sinonimos] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET ARITHABORT OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Projeto_sinonimos] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Projeto_sinonimos] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Projeto_sinonimos] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Projeto_sinonimos] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Projeto_sinonimos] SET  MULTI_USER 
GO
ALTER DATABASE [Projeto_sinonimos] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Projeto_sinonimos] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Projeto_sinonimos] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Projeto_sinonimos] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Projeto_sinonimos] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Projeto_sinonimos] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Projeto_sinonimos] SET QUERY_STORE = ON
GO
ALTER DATABASE [Projeto_sinonimos] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Modelo_redacao]

-- %%
USE [Projeto_sinonimos]
GO

-- %%
/****** Object:  Table [dbo].[Modelo_redacao]    Script Date: 29/08/2024 10:27:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Modelo_redacao](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[imagem] [varchar](300) NULL,
	[titulo] [varchar](50) NULL,
	[corpo_redacao] [varchar](2000) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Palavras]

-- %%
/****** Object:  Table [dbo].[Palavras]    Script Date: 29/08/2024 10:27:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Palavras](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[palavra] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sinonimos]

-- %%
/****** Object:  Table [dbo].[Sinonimos]    Script Date: 29/08/2024 10:27:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sinonimos](
	[idPalavra] [int] NULL,
	[sinonimo] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Sinonimos__idPal__48CFD27E]

-- %%
ALTER TABLE [dbo].[Sinonimos]  WITH CHECK ADD FOREIGN KEY([idPalavra])
REFERENCES [dbo].[Palavras] ([id])
GO

-- %% [markdown]
-- # [Projeto_sinonimos]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Projeto_sinonimos] SET  READ_WRITE 
GO
